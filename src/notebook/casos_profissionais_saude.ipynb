# %%
import sys
print(sys.executable)
# Out:
# c:\Program Files\Python312\python.exe

# %%
# Quantidade de profissionais da área da saúde
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Lê o arquivo CSV que está na mesma pasta
df = pd.read_csv('../../data/resultado.csv', delimiter=';', low_memory=False)

# %%
# Filtra os casos em que 'profissionalSaude' é igual a 'Sim'
saude_df = df[df['profissionalSaude'] == 'Sim']

# %%
# Remover o número e o hífen, mantendo apenas a descrição do CBO
saude_df['cbo_descricao'] = saude_df['cbo'].str.split(' - ').str[1]

# %%
# Conta a frequência de cada valor na coluna 'cbo_descricao'
saude_df.loc[:, 'cbo_descricao'] = saude_df['cbo'].str.split(' - ').str[1]

# %%
# Calcula o total de ocorrências
total_cbo = frequencia_cbo.sum()

# %%
# Calcula a porcentagem de cada CBO
porcentagem_cbo = (frequencia_cbo / total_cbo) * 100

# %%
# Cria um DataFrame com a quantidade e a porcentagem
resultado = pd.DataFrame({
    'Ocorrências': frequencia_cbo,
    'Porcentagem (%)': porcentagem_cbo
})

# %%
# Exibe o DataFrame no console
print(resultado)
# Out:
#                                                     Ocorrências  \
# cbo_descricao
# Técnicos e auxiliares de enfermagem                       15917
# Enfermeiros e afins                                        8594
# Agente Comunitário de Saúde                                2869
# Médico                                                     2845
# Farmacêuticos                                              1349
# ...                                                         ...
# Membros do ministério público                                 1
# Trabalhadores da preparação da confecção de roupas            1
# Tenentes do corpo de bombeiros militar                        1
# Engenheiros metalurgistas                                     1
# Oficiais superiores da polícia militar                        1
#
#                                                     Porcentagem (%)
# cbo_descricao
# Técnicos e auxiliares de enfermagem                       31.156044
# Enfermeiros e afins                                       16.821954
# Agente Comunitário de Saúde                                5.615800
# Médico                                                     5.568822
# Farmacêuticos                                              2.640542
# ...                                                             ...
# Membros do ministério público                              0.001957
# Trabalhadores da preparação da confecção de roupas         0.001957
# Tenentes do corpo de bombeiros militar                     0.001957
# Engenheiros metalurgistas                                  0.001957
# Oficiais superiores da polícia militar                     0.001957
#
# [301 rows x 2 columns]

# %%
# Seleciona as 5 áreas com maior ocorrência
top_5_cbo = frequencia_cbo.head(5)

# %%
# Plotando o gráfico de barras para as 5 maiores áreas de CBO (sem o número)
plt.figure(figsize=(10, 6))
top_5_cbo.plot(kind='bar', color='lightblue')
# Out:
# <Axes: xlabel='cbo_descricao'>

# %%
# Adiciona título e rótulos
plt.title('Top 5 Áreas de CBO para Profissionais da Saúde')
plt.xlabel('CBO')
plt.ylabel('Número de Ocorrências')
# Out:
# Text(0, 0.5, 'Número de Ocorrências')

# %%
# Rotaciona os rótulos do eixo X para melhorar a leitura
plt.xticks(rotation=45, ha='right')
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
# Exibe o gráfico
plt.tight_layout()
plt.show()

# %%
print('total de profissionais da saude:')
print(total_cbo)
# Out:
# total de profissionais da saude:
# 51088

# %%
print(frequencia_cbo.describe())
# Out:
# count      301.000000
# mean       169.727575
# std       1077.783546
# min          1.000000
# 25%          2.000000
# 50%          5.000000
# 75%         28.000000
# max      15917.000000
# Name: count, dtype: float64
